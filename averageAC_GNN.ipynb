# %%
! CUDA_VISIBLE_DEVICES=0 python train_averageAC_GNN.py --seed=42 \         --epochs=2000 \         --model=GCN \         --sens_number=200 \         --dataset=pokec_z \         --num-hidden=128 \         --acc=0.60 \         --roc=0.60 \         --alpha=100 \         --beta=1 \   --label_number=500
# averageAC+ GNN
# Out:
# Namespace(acc=0.6, alpha=100.0, attn_drop=0.0, attn_vec_dim=128, beta=1.0, cuda=True, dataset='pokec_z', dropout=0.5, epochs=2000, fastmode=False, feat_drop_rate=0.3, hidden=128, label_number=500, lr=0.001, model='GCN', negative_slope=0.2, no_cuda=False, num_heads=1, num_hidden=128, num_layers=1, num_out_heads=1, num_sen_class=1, residual=False, roc=0.6, seed=42, sens_number=200, transformed_feature_dim=128, weight_decay=1e-05)
# pokec_z
# region_job
# Loading region_job dataset from ../dataset/pokec/
# 2566
# Epoch: 0000, Cy_loss: 0.9980
# ...
# Epoch: 0000 cls: 0.9980
# Test: accuracy: 0.6056 roc: 0.6644 parity: 0.0334 equality: 0.0323
# Epoch: 0001, Cy_loss: 0.7045
# Epoch: 0002, Cy_loss: 0.7980
# Epoch: 0003, Cy_loss: 0.8269
# Epoch: 0004, Cy_loss: 0.7801
# Epoch: 0005, Cy_loss: 0.7174
# ...
# Epoch: 0005 cls: 0.7174
# Test: accuracy: 0.6422 roc: 0.6784 parity: 0.0217 equality: 0.0191
# Epoch: 0006, Cy_loss: 0.6932
# Epoch: 0007, Cy_loss: 0.7100
# Epoch: 0008, Cy_loss: 0.7426
# ...

# %%
! CUDA_VISIBLE_DEVICES=0 python train_fairAC_GNN_end2end.py --seed=42 \         --epochs=2000 \         --model=GCN \         --sens_number=200 \         --dataset=pokec_z \         --num-hidden=128 \         --acc=0.65 \         --roc=0.70 \         --alpha=100 \         --beta=1 \   --label_number=500
# fairAC+ GNN end2end
# Out:
# Namespace(acc=0.65, alpha=100.0, attn_drop=0.0, attn_vec_dim=128, beta=1.0, cuda=True, dataset='pokec_z', dropout=0.5, epochs=2000, fastmode=False, feat_drop_rate=0.3, hidden=128, label_number=500, lr=0.001, model='GCN', negative_slope=0.2, no_cuda=False, num_heads=1, num_hidden=128, num_layers=1, num_out_heads=1, num_sen_class=1, residual=False, roc=0.7, seed=42, sens_number=200, transformed_feature_dim=128, weight_decay=1e-05)
# pokec_z
# region_job
# Loading region_job dataset from ../dataset/pokec/
# 2566
# Epoch: 0000, loss_ac: 55.1020, loss_reconstruction: 103.6931
# Epoch: 0001, loss_ac: 54.3295, loss_reconstruction: 96.2002
# Epoch: 0002, loss_ac: 52.9838, loss_reconstruction: 89.6175
# Epoch: 0003, loss_ac: 52.9147, loss_reconstruction: 83.3845
# Epoch: 0004, loss_ac: 51.8993, loss_reconstruction: 77.7147
# Epoch: 0005, loss_ac: 50.7481, loss_reconstruction: 73.1136
# Epoch: 0006, loss_ac: 50.0458, loss_reconstruction: 68.2420
# ...

# %%
! CUDA_VISIBLE_DEVICES=5 python train_fairAC_GNN_end2end.py --seed=42 \         --epochs=2000 \         --model=GCN \         --sens_number=200 \         --dataset=pokec_z \         --num-hidden=128 \         --acc=0.65 \         --roc=0.70 \         --alpha=100 \         --beta=1 \   --label_number=500
# fairAC+ GNN end2end
# without loss_reconstruction, lin 256
# line 260
# Out:
# Namespace(acc=0.65, alpha=100.0, attn_drop=0.0, attn_vec_dim=128, beta=1.0, cuda=True, dataset='pokec_z', dropout=0.5, epochs=2000, fastmode=False, feat_drop_rate=0.3, hidden=128, label_number=500, lr=0.001, model='GCN', negative_slope=0.2, no_cuda=False, num_heads=1, num_hidden=128, num_layers=1, num_out_heads=1, num_sen_class=1, residual=False, roc=0.7, seed=42, sens_number=200, transformed_feature_dim=128, weight_decay=1e-05)
# pokec_z
# region_job
# Loading region_job dataset from ../dataset/pokec/
# 2566
# Epoch: 0000, loss_ac: 55.1020, loss_reconstruction: 0.0000, Csen_loss: 0.9557, Csen_adv_loss: 0.7369, Cy_loss: 0.9063
# Epoch: 0001, loss_ac: 53.6964, loss_reconstruction: 0.0000, Csen_loss: 0.7899, Csen_adv_loss: 0.7098, Cy_loss: 0.8814
# Epoch: 0002, loss_ac: 51.8006, loss_reconstruction: 0.0000, Csen_loss: 0.7037, Csen_adv_loss: 0.7283, Cy_loss: 0.8383
# Epoch: 0003, loss_ac: 51.2463, loss_reconstruction: 0.0000, Csen_loss: 0.667, Csen_adv_loss: 0.7644, Cy_loss: 0.6827
# ...
